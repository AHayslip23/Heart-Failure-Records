# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
heart = pd.read_csv('heart failure records.csv')

# %%
heart
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
heart.age = heart.age.astype(int)

# %%
heart.platelets = heart.platelets.astype(int)

# %%
heart
# Out:
#      age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0     75        0                       582         0                 20
# 1     55        0                      7861         0                 38
# 2     65        0                       146         0                 20
# 3     50        1                       111         0                 20
# 4     65        1                       160         1                 20
# ..   ...      ...                       ...       ...                ...
# 294   62        0                        61         1                 38
# 295   55        0                      1820         0                 38
# 296   45        0                      2060         1                 60
# 297   45        0                      2413         0                 38
# 298   50        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
#histogram of ages

# %%
age = plt.hist(heart.age, bins=15)

# %%
#most candiate are in their late 50's and early 60's

# %%
followup = plt.hist(heart.time, bins=15)

# %%
#most people have follow up times between 75 and 90 days

# %%
ejectionfraction = plt.hist(heart.ejection_fraction, bins=10)

# %%
#it appears that the ejection is between 35 and 40 ejection fractions

# %%
#count death, sex smoking and high blood pressure

# %%
death = sns.countplot(x='DEATH_EVENT', data=heart)

# %%
#most of the heart attack patients survived

# %%
smoking = sns.countplot(x='smoking', data=heart)

# %%
#most of the patients did not smoke

# %%
highbloodpressure = sns.countplot(x="high_blood_pressure", data=heart)

# %%
#most of the patients did not have high blood pressure

# %%
sex = sns.countplot(x="sex", data=heart)

# %%
#most of the patients have sex

# %%
#is there anemia and diabets

# %%
diabetes = sns.countplot(x="diabetes", data=heart)

# %%
#most patients do not have diabetes

# %%
#anaemia

# %%
anaemia = sns.countplot(x="anaemia", data=heart)

# %%
#most patient do not have anaemia

# %%
#correaltion between serum creatine and serum sodium

# %%
machinelearning1 = heart[["serum_creatinine", "serum_sodium"]]

# %%
machinelearning1
# Out:
#      serum_creatinine  serum_sodium
# 0                 1.9           130
# 1                 1.1           136
# 2                 1.3           129
# 3                 1.9           137
# 4                 2.7           116
# ..                ...           ...
# 294               1.1           143
# 295               1.2           139
# 296               0.8           138
# 297               1.4           140
# 298               1.6           136
#
# [299 rows x 2 columns]

# %%
X = machinelearning1.iloc[:, :-1].values
Y = machinelearning1.iloc[:, -1].values

# %%
X
# Out:
# array([[1.9 ],
#        [1.1 ],
#        [1.3 ],
#        [1.9 ],
#        [2.7 ],
#        [2.1 ],
#        [1.2 ],
#        [1.1 ],
#        [1.5 ],
#        [9.4 ],
#        [4.  ],
#        [0.9 ],
#        [1.1 ],
#        [1.1 ],
#        [1.  ],
#        [1.3 ],
#        [0.9 ],
#        [0.8 ],
#        [1.  ],
#        [1.9 ],
#        [1.3 ],
#        [1.6 ],
#        [0.9 ],
#        [0.8 ],
#        [1.83],
#        [1.9 ],
#        [1.  ],
#        [1.3 ],
#        [5.8 ],
#        [1.2 ],
#        [1.83],
#        [3.  ],
#        [1.  ],
#        [1.2 ],
#        [1.  ],
#        [3.5 ],
#        [1.  ],
#        [1.  ],
#        [2.3 ],
#        [3.  ],
#        [1.83],
#        [1.2 ],
#        [1.2 ],
#        [1.  ],
#        [1.1 ],
#        [1.9 ],
#        [0.9 ],
#        [0.6 ],
#        [4.4 ],
#        [1.  ],
#        [1.  ],
#        [1.4 ],
#        [6.8 ],
#        [1.  ],
#        [2.2 ],
#        [2.  ],
#        [2.7 ],
#        [0.6 ],
# ...

# %%
Y
# Out:
# array([130, 136, 129, 137, 116, 132, 137, 131, 138, 133, 131, 140, 137,
#        137, 138, 136, 140, 127, 140, 121, 137, 136, 140, 135, 134, 144,
#        138, 136, 134, 132, 134, 132, 128, 138, 140, 134, 134, 145, 137,
#        142, 134, 136, 139, 134, 142, 135, 130, 138, 133, 140, 138, 139,
#        146, 134, 132, 132, 138, 138, 136, 136, 139, 131, 139, 145, 137,
#        127, 136, 140, 142, 135, 140, 139, 132, 137, 134, 139, 140, 140,
#        131, 140, 136, 137, 132, 133, 141, 140, 137, 140, 139, 144, 136,
#        133, 137, 135, 142, 141, 134, 136, 137, 140, 141, 137, 144, 140,
#        143, 138, 137, 138, 133, 142, 132, 135, 136, 137, 126, 139, 136,
#        138, 140, 134, 135, 136, 140, 145, 134, 135, 124, 137, 136, 145,
#        138, 131, 137, 145, 137, 137, 137, 130, 136, 138, 134, 140, 132,
#        141, 139, 141, 136, 137, 134, 136, 135, 139, 134, 137, 136, 140,
#        136, 136, 134, 139, 134, 139, 137, 142, 139, 135, 133, 134, 138,
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
X_train
# Out:
# array([[0.8 ],
#        [1.  ],
#        [1.1 ],
#        [1.5 ],
#        [1.18],
#        [0.9 ],
#        [1.2 ],
#        [1.  ],
#        [1.4 ],
#        [1.1 ],
#        [0.8 ],
#        [1.  ],
#        [0.8 ],
#        [1.2 ],
#        [1.1 ],
#        [2.7 ],
#        [1.1 ],
#        [1.3 ],
#        [0.9 ],
#        [0.9 ],
#        [1.3 ],
#        [1.18],
#        [2.2 ],
#        [1.  ],
#        [1.  ],
#        [1.  ],
#        [1.  ],
#        [2.1 ],
#        [0.9 ],
#        [0.9 ],
#        [1.4 ],
#        [0.9 ],
#        [0.8 ],
#        [1.  ],
#        [1.6 ],
#        [0.8 ],
#        [1.1 ],
#        [1.2 ],
#        [1.8 ],
#        [2.4 ],
#        [1.  ],
#        [2.4 ],
#        [1.3 ],
#        [1.2 ],
#        [1.6 ],
#        [1.2 ],
#        [0.7 ],
#        [0.9 ],
#        [2.7 ],
#        [0.7 ],
#        [1.3 ],
#        [1.  ],
#        [0.7 ],
#        [0.8 ],
#        [2.7 ],
#        [1.3 ],
#        [0.7 ],
#        [2.3 ],
# ...

# %%
X_test
# Out:
# array([[0.8 ],
#        [1.  ],
#        [1.1 ],
#        [0.7 ],
#        [1.2 ],
#        [0.9 ],
#        [5.  ],
#        [1.  ],
#        [6.8 ],
#        [1.1 ],
#        [1.3 ],
#        [1.3 ],
#        [1.2 ],
#        [1.1 ],
#        [0.9 ],
#        [1.2 ],
#        [1.  ],
#        [0.8 ],
#        [1.  ],
#        [1.  ],
#        [2.1 ],
#        [1.  ],
#        [3.7 ],
#        [3.4 ],
#        [1.83],
#        [0.7 ],
#        [1.6 ],
#        [1.2 ],
#        [1.1 ],
#        [1.2 ],
#        [1.18],
#        [1.3 ],
#        [1.5 ],
#        [0.75],
#        [9.  ],
#        [2.5 ],
#        [1.  ],
#        [1.2 ],
#        [1.6 ],
#        [2.1 ],
#        [1.  ],
#        [1.1 ],
#        [1.18],
#        [1.  ],
#        [2.  ],
#        [0.8 ],
#        [1.1 ],
#        [1.18],
#        [1.1 ],
#        [1.9 ],
#        [1.3 ],
#        [1.4 ],
#        [0.8 ],
#        [1.3 ],
#        [1.3 ],
#        [1.7 ],
#        [1.  ],
#        [1.  ],
# ...

# %%
Y_train
# Out:
# array([135, 145, 136, 135, 137, 140, 134, 136, 138, 148, 140, 136, 134,
#        132, 137, 136, 142, 136, 140, 134, 134, 137, 132, 136, 140, 137,
#        142, 124, 140, 139, 125, 134, 134, 132, 130, 136, 139, 138, 133,
#        135, 139, 134, 136, 132, 136, 132, 136, 140, 138, 139, 142, 138,
#        137, 139, 116, 134, 133, 131, 140, 130, 137, 133, 136, 134, 140,
#        137, 138, 134, 137, 136, 135, 134, 134, 140, 142, 141, 121, 133,
#        134, 140, 136, 139, 129, 137, 143, 140, 137, 131, 134, 136, 136,
#        138, 140, 138, 130, 137, 145, 113, 139, 144, 138, 138, 136, 135,
#        134, 126, 136, 136, 141, 136, 136, 137, 137, 134, 135, 145, 137,
#        134, 145, 137, 130, 142, 141, 139, 138, 136, 135, 140, 133, 140,
#        138, 140, 135, 139, 134, 141, 131, 136, 141, 137, 131, 134, 140,
#        137, 137, 142, 136, 141, 136, 136, 134, 139, 140, 132, 139, 133,
#        132, 128, 140, 134, 144, 134, 138, 133, 134, 127, 136, 135, 141,
# ...

# %%
Y_test
# Out:
# array([141, 136, 137, 140, 132, 137, 130, 136, 146, 133, 139, 136, 137,
#        138, 140, 134, 132, 136, 140, 142, 134, 140, 134, 145, 134, 136,
#        135, 135, 143, 130, 137, 136, 138, 140, 137, 135, 135, 136, 136,
#        132, 140, 144, 137, 140, 132, 138, 137, 137, 131, 135, 137, 139,
#        139, 137, 136, 127, 138, 138, 138, 137, 137, 141, 145, 140, 141,
#        139, 144, 135, 137, 130, 136, 132, 133, 136, 139], dtype=int64)

# %%
#no feature scaling

# %%
#linear regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#create y_pred

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([137.24700667, 136.98573074, 136.85509278, 137.37764463,
#        136.72445482, 137.11636871, 131.76021221, 136.98573074,
#        129.40872887, 136.85509278, 136.59381685, 136.59381685,
#        136.72445482, 136.85509278, 137.11636871, 136.72445482,
#        136.98573074, 137.24700667, 136.98573074, 136.98573074,
#        135.54871315, 136.98573074, 133.45850573, 133.85041962,
#        135.90143565, 137.37764463, 136.20190296, 136.72445482,
#        136.85509278, 136.72445482, 136.75058241, 136.59381685,
#        136.33254093, 137.31232565, 126.53469368, 135.02616129,
#        136.98573074, 136.72445482, 136.20190296, 135.54871315,
#        136.98573074, 136.85509278, 136.75058241, 136.98573074,
#        135.67935111, 137.24700667, 136.85509278, 136.75058241,
#        136.85509278, 135.80998907, 136.59381685, 136.46317889,
#        137.24700667, 136.59381685, 136.59381685, 136.071265  ,
#        136.98573074, 136.98573074, 136.85509278, 136.75058241,
# ...

# %%
y_pred
# Out:
# array([137.24700667, 136.98573074, 136.85509278, 137.37764463,
#        136.72445482, 137.11636871, 131.76021221, 136.98573074,
#        129.40872887, 136.85509278, 136.59381685, 136.59381685,
#        136.72445482, 136.85509278, 137.11636871, 136.72445482,
#        136.98573074, 137.24700667, 136.98573074, 136.98573074,
#        135.54871315, 136.98573074, 133.45850573, 133.85041962,
#        135.90143565, 137.37764463, 136.20190296, 136.72445482,
#        136.85509278, 136.72445482, 136.75058241, 136.59381685,
#        136.33254093, 137.31232565, 126.53469368, 135.02616129,
#        136.98573074, 136.72445482, 136.20190296, 135.54871315,
#        136.98573074, 136.85509278, 136.75058241, 136.98573074,
#        135.67935111, 137.24700667, 136.85509278, 136.75058241,
#        136.85509278, 135.80998907, 136.59381685, 136.46317889,
#        137.24700667, 136.59381685, 136.59381685, 136.071265  ,
#        136.98573074, 136.98573074, 136.85509278, 136.75058241,
# ...

# %%
plt.scatter(X_train, Y_train, color = "red")
plt.plot(X_train, regressor.predict(X_train), color = "blue")
plt.title("Correalation for Serum Creatinine and Serum Sodium")
plt.xlabel("Serum Creatinine")
plt.ylabel("Serrum Sodium") 
plt.show()

# %%
from sklearn.metrics import r2_score 
r2_score(Y_test, y_pred)
# Out:
# -0.2228077801995112

# %%
#-0.22 accuracy

# %%
#correlation between age and time

# %%
machinelearning2 = heart[["age", "time"]]

# %%
machinelearning2
# Out:
#      age  time
# 0     75     4
# 1     55     6
# 2     65     7
# 3     50     7
# 4     65     8
# ..   ...   ...
# 294   62   270
# 295   55   271
# 296   45   278
# 297   45   280
# 298   50   285
#
# [299 rows x 2 columns]

# %%
X = machinelearning2.iloc[:, :-1].values 
Y = machinelearning2.iloc[:, -1].values

# %%
X
# Out:
# array([[75],
#        [55],
#        [65],
#        [50],
#        [65],
#        [90],
#        [75],
#        [60],
#        [65],
#        [80],
#        [75],
#        [62],
#        [45],
#        [50],
#        [49],
#        [82],
#        [87],
#        [45],
#        [70],
#        [48],
#        [65],
#        [65],
#        [68],
#        [53],
#        [75],
#        [80],
#        [95],
#        [70],
#        [58],
#        [82],
#        [94],
#        [85],
#        [50],
#        [50],
#        [65],
#        [69],
#        [90],
#        [82],
#        [60],
#        [60],
#        [70],
#        [50],
#        [70],
#        [72],
#        [60],
#        [50],
#        [51],
#        [60],
#        [80],
#        [57],
#        [68],
#        [53],
#        [60],
#        [70],
#        [60],
#        [95],
#        [70],
#        [60],
#        [49],
#        [72],
#        [45],
#        [50],
#        [55],
#        [45],
#        [45],
#        [60],
# ...

# %%
Y
# Out:
# array([  4,   6,   7,   7,   8,   8,  10,  10,  10,  10,  10,  10,  11,
#         11,  12,  13,  14,  14,  15,  15,  16,  20,  20,  22,  23,  23,
#         24,  26,  26,  26,  27,  28,  28,  29,  29,  30,  30,  30,  30,
#         30,  31,  32,  33,  33,  33,  35,  38,  40,  41,  42,  43,  43,
#         43,  44,  45,  50,  54,  54,  55,  59,  60,  60,  60,  61,  63,
#         64,  65,  65,  66,  67,  68,  71,  72,  72,  73,  73,  74,  74,
#         74,  74,  75,  76,  77,  78,  78,  79,  79,  79,  79,  79,  80,
#         80,  82,  82,  83,  83,  83,  85,  85,  86,  87,  87,  87,  87,
#         87,  88,  88,  88,  88,  88,  90,  90,  90,  90,  91,  91,  94,
#         94,  94,  95,  95,  95,  95,  95,  96,  97, 100, 104, 104, 105,
#        106, 107, 107, 107, 107, 107, 107, 108, 108, 108, 109, 109, 109,
#        110, 111, 112, 112, 113, 113, 115, 115, 117, 118, 119, 120, 120,
#        120, 120, 121, 121, 121, 121, 123, 126, 129, 130, 134, 135, 140,
# ...

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
X_train
# Out:
# array([[45],
#        [82],
#        [70],
#        [64],
#        [75],
#        [65],
#        [66],
#        [45],
#        [78],
#        [75],
#        [70],
#        [70],
#        [47],
#        [70],
#        [77],
#        [70],
#        [60],
#        [65],
#        [40],
#        [50],
#        [85],
#        [75],
#        [60],
#        [59],
#        [70],
#        [70],
#        [40],
#        [46],
#        [52],
#        [58],
#        [75],
#        [51],
#        [65],
#        [45],
#        [48],
#        [65],
#        [59],
#        [50],
#        [79],
#        [64],
#        [45],
#        [59],
#        [55],
#        [85],
#        [65],
#        [82],
#        [52],
#        [87],
#        [70],
#        [60],
#        [45],
#        [60],
#        [63],
#        [45],
#        [65],
#        [63],
#        [53],
#        [50],
#        [72],
#        [68],
#        [60],
#        [62],
#        [50],
#        [70],
#        [56],
#        [50],
# ...

# %%
X_test
# Out:
# array([[40],
#        [60],
#        [45],
#        [55],
#        [70],
#        [65],
#        [65],
#        [50],
#        [60],
#        [63],
#        [70],
#        [82],
#        [58],
#        [55],
#        [68],
#        [69],
#        [40],
#        [70],
#        [55],
#        [52],
#        [80],
#        [42],
#        [60],
#        [53],
#        [73],
#        [60],
#        [45],
#        [55],
#        [62],
#        [53],
#        [42],
#        [42],
#        [65],
#        [60],
#        [54],
#        [72],
#        [69],
#        [65],
#        [50],
#        [90],
#        [68],
#        [57],
#        [67],
#        [65],
#        [95],
#        [50],
#        [53],
#        [45],
#        [60],
#        [50],
#        [65],
#        [60],
#        [50],
#        [55],
#        [72],
#        [60],
#        [65],
#        [95],
#        [65],
#        [50],
#        [81],
#        [50],
#        [45],
#        [52],
#        [50],
#        [42],
# ...

# %%
Y_train
# Out:
# array([230,  30,  85, 174, 107,  94, 121, 186, 192, 209,  74, 188, 201,
#        215, 209, 250,  33, 212, 174, 118, 121,  87,  45, 150,  15, 247,
#        214, 100, 146,  71, 205, 244, 194, 250, 193, 120, 121,  29,  78,
#        214,  60, 135, 246,  90,  20,  26, 112,  14,  54,  73,  88, 146,
#        186, 121,   8,  83, 134,  60,  65, 108, 245, 233, 246,  31, 244,
#         11,  88, 197,   7, 120,  97,  23,  27,  74, 245, 187,  15, 215,
#        207, 244,  75,  43,   7, 209,  87, 147,  79,  10, 186,  55,  32,
#         12, 120,  43, 187, 211,  95, 186,  60, 172, 205, 106, 187, 231,
#         33,  91, 108, 270, 196, 115,  90, 213,  85, 195,  82, 200, 123,
#         30, 147,  90,   4,  83,  83, 271, 233, 210,  67,  42,  41,  79,
#        278, 109,  22, 214, 113, 110,  74, 148,  87, 187, 107, 241, 280,
#        185,  10,  66, 187,  78, 145,  95, 109, 215, 245, 109, 220,  80,
#         77, 250,  10,  95,  87,  30,  54, 145, 208,  64,   6,  95, 237,
# ...

# %%
Y_test
# Out:
# array([187, 172,  11, 197, 210, 107, 207, 187,  43,  88, 212,  13, 170,
#        214,  20,  73, 244,  80, 206, 216, 174,  87,  96, 105, 198,  94,
#        180, 250, 270, 214,  82,  65,  10,  95, 196, 115, 147, 154, 285,
#          8, 237,  79,  76,  29,  50, 108, 209,  63,  10,  35,  72, 258,
#        146,  88,  59, 207, 140,  24, 250, 119, 107, 112,  61, 258, 250,
#        201, 256,  90,  16,  38, 120, 205, 245,  26, 111], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([161.63953796, 130.57180748, 153.87260534, 138.3387401 ,
#        115.03794224, 122.80487486, 122.80487486, 146.10567272,
#        130.57180748, 125.91164791, 115.03794224,  96.39730395,
#        133.67858053, 138.3387401 , 118.14471529, 116.59132877,
#        161.63953796, 115.03794224, 138.3387401 , 142.99889967,
#         99.504077  , 158.53276491, 130.57180748, 141.44551315,
#        110.37778267, 130.57180748, 153.87260534, 138.3387401 ,
#        127.46503443, 141.44551315, 158.53276491, 158.53276491,
#        122.80487486, 130.57180748, 139.89212662, 111.93116919,
#        116.59132877, 122.80487486, 146.10567272,  83.97021176,
#        118.14471529, 135.23196705, 119.69810181, 122.80487486,
#         76.20327914, 146.10567272, 141.44551315, 153.87260534,
#        130.57180748, 146.10567272, 122.80487486, 130.57180748,
#        146.10567272, 138.3387401 , 111.93116919, 130.57180748,
#        122.80487486,  76.20327914, 122.80487486, 146.10567272,
# ...

# %%
plt.scatter(X_train, Y_train, color ="black")
plt.plot(X_train, regressor.predict(X_train), color = "red")
plt.title("Correation vs Age and Time")
plt.xlabel("Age")
plt.ylabel("Time")
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, y_pred)
# Out:
# 0.030618334983430695

# %%
#there is a 3.06% correaltion between age and time

# %%
#is there any correlation between creatinine_phosphokinase and platelets

# %%
machinelearning3 = heart[["platelets", "creatinine_phosphokinase"]]

# %%
machinelearning3
# Out:
#      platelets  creatinine_phosphokinase
# 0       265000                       582
# 1       263358                      7861
# 2       162000                       146
# 3       210000                       111
# 4       327000                       160
# ..         ...                       ...
# 294     155000                        61
# 295     270000                      1820
# 296     742000                      2060
# 297     140000                      2413
# 298     395000                       196
#
# [299 rows x 2 columns]

# %%
X = machinelearning3.iloc[:, :-1].values
Y = machinelearning3.iloc[:, -1].values

# %%
X
# Out:
# array([[265000],
#        [263358],
#        [162000],
#        [210000],
#        [327000],
#        [204000],
#        [127000],
#        [454000],
#        [263358],
#        [388000],
#        [368000],
#        [253000],
#        [136000],
#        [276000],
#        [427000],
#        [ 47000],
#        [262000],
#        [166000],
#        [237000],
#        [ 87000],
#        [276000],
#        [297000],
#        [289000],
#        [368000],
#        [263358],
#        [149000],
#        [196000],
#        [284000],
#        [153000],
#        [200000],
#        [263358],
#        [360000],
#        [319000],
#        [302000],
#        [188000],
#        [228000],
#        [226000],
#        [321000],
#        [305000],
#        [329000],
#        [263358],
#        [153000],
#        [185000],
#        [218000],
#        [194000],
#        [310000],
#        [271000],
#        [451000],
#        [140000],
#        [395000],
#        [166000],
#        [418000],
# ...

# %%
Y
# Out:
# array([ 582, 7861,  146,  111,  160,   47,  246,  315,  157,  123,   81,
#         231,  981,  168,   80,  379,  149,  582,  125,  582,   52,  128,
#         220,   63,  582,  148,  112,  122,   60,   70,  582,   23,  249,
#         159,   94,  582,   60,  855, 2656,  235,  582,  124,  571,  127,
#         588,  582, 1380,  582,  553,  129,  577,   91, 3964,   69,  260,
#         371,   75,  607,  789,  364, 7702,  318,  109,  582,  582,   68,
#         250,  110,  161,  113,  148,  582, 5882,  224,  582,   47,   92,
#         102,  203,  336,   69,  582,   76,   55,  280,   78,   47,   68,
#          84,  115,   66,  897,  582,  154,  144,  133,  514,   59,  156,
#          61,  305,  582,  898, 5209,   53,  328,  748, 1876,  936,  292,
#         129,   60,  369,  143,  754,  400,   96,  102,  113,  582,  737,
#          68,   96,  582,  582,  358,  168,  200,  248,  270, 1808, 1082,
#         719,  193, 4540,  582,   59,  646,  281, 1548,  805,  291,  482,
# ...

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=0)

# %%
X_train
# Out:
# array([[231000],
#        [266000],
#        [385000],
#        [382000],
#        [279000],
#        [365000],
#        [390000],
#        [228000],
#        [276000],
#        [271000],
#        [277000],
#        [189000],
#        [215000],
#        [284000],
#        [338000],
#        [233000],
#        [321000],
#        [255000],
#        [309000],
#        [263358],
#        [203000],
#        [242000],
#        [377000],
#        [481000],
#        [248000],
#        [317000],
#        [389000],
#        [130000],
#        [236000],
#        [406000],
#        [ 51000],
#        [194000],
#        [249000],
#        [275000],
#        [184000],
#        [235000],
#        [263358],
#        [255000],
#        [221000],
#        [237000],
#        [241000],
#        [301000],
#        [271000],
#        [325000],
#        [122000],
#        [265000],
#        [221000],
#        [290000],
#        [543000],
#        [244000],
#        [235000],
#        [362000],
# ...

# %%
X_test
# Out:
# array([[226000],
#        [201000],
#        [136000],
#        [371000],
#        [173000],
#        [172000],
#        [237000],
#        [362000],
#        [263358],
#        [304000],
#        [533000],
#        [ 47000],
#        [219000],
#        [314000],
#        [289000],
#        [266000],
#        [222000],
#        [249000],
#        [141000],
#        [334000],
#        [350000],
#        [226000],
#        [217000],
#        [227000],
#        [263358],
#        [271000],
#        [126000],
#        [336000],
#        [155000],
#        [223000],
#        [263358],
#        [213000],
#        [263358],
#        [228000],
#        [151000],
#        [235000],
#        [105000],
#        [265000],
#        [395000],
#        [204000],
#        [208000],
#        [181000],
#        [263358],
#        [188000],
#        [461000],
#        [211000],
#        [305000],
#        [263358],
#        [454000],
#        [310000],
#        [149000],
#        [133000],
# ...

# %%
Y_train
# Out:
# array([4540,  185,  582,  190,   54,   86,  337,   60,   52, 1380,   58,
#          57,  213,  122,  943,   66,  855,   59,   62,  582,  113,   72,
#         308,  224,  119,   92,  212,  582,   88,  109,  582,  588,  582,
#         244,  115,  910,  582,  260,  176,  125, 2695,  624,  168, 3966,
#         582,  675,  582,  135,  582,  131,  335,  129,  159,   55,  143,
#        7702,   66,   84,  129,  128,   70,  132,  149,   75,   47,  292,
#          95, 1767,  130,  160,  514,  196,  318,  110,  646,  257,  655,
#        1051,  582,  135,  168, 1876, 1021,  111,  250,  358,  582,  582,
#         102,  618, 2281,  582,  245,  211,  582,   69,   91,  146,  707,
#          53,  835,   47,   81,  582,  789,  124,   80,  231,  577,  972,
#         180,  582, 1211,  109, 1896,  582, 1808,  212,   56,  127,  754,
#         281,  103, 1202, 2261,  369,   80,  156,  582,  154,  118,  582,
#          60,  122,  143,  582,  144,  133, 1820,   66,  720,  113,  129,
# ...

# %%
Y_test
# Out:
# array([ 101,  151,  981,  582,  232,   59,   56,  167, 3964,  936,   81,
#         379,  145, 2017,  220,  582,  582,   66, 2794,  191,  582, 5209,
#         582,  270,  582,   96,  582,  170,   61,  207,  582,  250,  157,
#          96,  427,  233, 1419,  395,  196,   47,  157,  115,  582,   94,
#         371, 1548,  582,  582,  315,  582,  224,  320,  115,  748,  364,
#         166,  582,  112, 1688, 1846], dtype=int64)

# %%
#linear regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([553.41409729, 543.0277634 , 516.02329531, 613.6548338 ,
#        531.39506945, 530.9796161 , 557.98408419, 609.91575361,
#        568.93460373, 585.819459  , 680.95827736, 479.04794669,
#        550.5059238 , 589.97399255, 579.58765867, 570.0322315 ,
#        551.75228386, 562.96952446, 518.10056208, 598.28305966,
#        604.93031334, 553.41409729, 549.67501709, 553.82955064,
#        568.93460373, 572.10949827, 511.86876175, 599.11396637,
#        523.91690906, 552.16773722, 568.93460373, 548.01320367,
#        568.93460373, 554.245004  , 522.25509564, 557.15317748,
#        503.14424129, 569.61677814, 623.62571433, 544.27412347,
#        545.93593689, 534.7186963 , 568.93460373, 537.62686978,
#        651.04563578, 547.18229696, 586.23491235, 568.93460373,
#        648.13746229, 588.31217913, 521.42418893, 514.77693524,
#        538.04232314, 568.78587143, 565.04679123, 485.27974702,
#        571.69404492, 540.95049663, 568.93460373, 568.93460373])

# %%
plt.scatter(X_train, Y_train, color ="green")
plt.plot(X_train, regressor.predict(X_train), color="red")
plt.title("Correlation of creatinine phosphokinase vs platelets ")
plt.xlabel("creatinine phosphokinase")
plt.ylabel("platelets")
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, y_pred)
# Out:
# -0.010195276196816483

# %%
#-0.01 correaltion

# %%
machinelearning4 = heart[["ejection_fraction", "creatinine_phosphokinase"]]

# %%
machinelearning4
# Out:
#      ejection_fraction  creatinine_phosphokinase
# 0                   20                       582
# 1                   38                      7861
# 2                   20                       146
# 3                   20                       111
# 4                   20                       160
# ..                 ...                       ...
# 294                 38                        61
# 295                 38                      1820
# 296                 60                      2060
# 297                 38                      2413
# 298                 45                       196
#
# [299 rows x 2 columns]

# %%
X = machinelearning4.iloc[:, :-1].values
Y = machinelearning4.iloc[:, -1].values

# %%
X
# Out:
# array([[20],
#        [38],
#        [20],
#        [20],
#        [20],
#        [40],
#        [15],
#        [60],
#        [65],
#        [35],
#        [38],
#        [25],
#        [30],
#        [38],
#        [30],
#        [50],
#        [38],
#        [14],
#        [25],
#        [55],
#        [25],
#        [30],
#        [35],
#        [60],
#        [30],
#        [38],
#        [40],
#        [45],
#        [38],
#        [30],
#        [38],
#        [45],
#        [35],
#        [30],
#        [50],
#        [35],
#        [50],
#        [50],
#        [30],
#        [38],
#        [20],
#        [30],
#        [45],
#        [50],
#        [60],
#        [38],
#        [25],
#        [38],
#        [20],
#        [30],
#        [25],
#        [20],
#        [62],
#        [50],
#        [38],
#        [30],
#        [35],
#        [40],
#        [20],
#        [20],
#        [25],
#        [40],
#        [35],
#        [35],
#        [80],
#        [20],
# ...

# %%
Y
# Out:
# array([ 582, 7861,  146,  111,  160,   47,  246,  315,  157,  123,   81,
#         231,  981,  168,   80,  379,  149,  582,  125,  582,   52,  128,
#         220,   63,  582,  148,  112,  122,   60,   70,  582,   23,  249,
#         159,   94,  582,   60,  855, 2656,  235,  582,  124,  571,  127,
#         588,  582, 1380,  582,  553,  129,  577,   91, 3964,   69,  260,
#         371,   75,  607,  789,  364, 7702,  318,  109,  582,  582,   68,
#         250,  110,  161,  113,  148,  582, 5882,  224,  582,   47,   92,
#         102,  203,  336,   69,  582,   76,   55,  280,   78,   47,   68,
#          84,  115,   66,  897,  582,  154,  144,  133,  514,   59,  156,
#          61,  305,  582,  898, 5209,   53,  328,  748, 1876,  936,  292,
#         129,   60,  369,  143,  754,  400,   96,  102,  113,  582,  737,
#          68,   96,  582,  582,  358,  168,  200,  248,  270, 1808, 1082,
#         719,  193, 4540,  582,   59,  646,  281, 1548,  805,  291,  482,
# ...

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=0)

# %%
X_train
# Out:
# array([[35],
#        [30],
#        [35],
#        [38],
#        [40],
#        [35],
#        [38],
#        [35],
#        [25],
#        [25],
#        [35],
#        [25],
#        [38],
#        [45],
#        [25],
#        [25],
#        [50],
#        [60],
#        [60],
#        [40],
#        [60],
#        [40],
#        [60],
#        [50],
#        [50],
#        [60],
#        [17],
#        [25],
#        [35],
#        [50],
#        [40],
#        [60],
#        [30],
#        [45],
#        [45],
#        [50],
#        [45],
#        [38],
#        [25],
#        [25],
#        [40],
#        [35],
#        [17],
#        [40],
#        [35],
#        [60],
#        [40],
#        [35],
#        [55],
#        [30],
#        [35],
#        [45],
#        [30],
#        [50],
#        [25],
#        [25],
#        [20],
#        [38],
#        [60],
#        [30],
#        [30],
#        [30],
#        [38],
#        [35],
#        [20],
#        [35],
# ...

# %%
X_test
# Out:
# array([[40],
#        [40],
#        [30],
#        [35],
#        [30],
#        [60],
#        [25],
#        [45],
#        [62],
#        [38],
#        [35],
#        [50],
#        [25],
#        [25],
#        [35],
#        [20],
#        [35],
#        [45],
#        [35],
#        [30],
#        [35],
#        [30],
#        [40],
#        [35],
#        [20],
#        [60],
#        [20],
#        [40],
#        [38],
#        [40],
#        [60],
#        [15],
#        [65],
#        [38],
#        [70],
#        [45],
#        [40],
#        [25],
#        [45],
#        [40],
#        [60],
#        [25],
#        [50],
#        [50],
#        [30],
#        [30],
#        [45],
#        [80],
#        [60],
#        [38],
#        [50],
#        [35],
#        [20],
#        [45],
#        [20],
#        [30],
#        [40],
#        [40],
#        [38],
#        [35]], dtype=int64)

# %%
Y_train
# Out:
# array([4540,  185,  582,  190,   54,   86,  337,   60,   52, 1380,   58,
#          57,  213,  122,  943,   66,  855,   59,   62,  582,  113,   72,
#         308,  224,  119,   92,  212,  582,   88,  109,  582,  588,  582,
#         244,  115,  910,  582,  260,  176,  125, 2695,  624,  168, 3966,
#         582,  675,  582,  135,  582,  131,  335,  129,  159,   55,  143,
#        7702,   66,   84,  129,  128,   70,  132,  149,   75,   47,  292,
#          95, 1767,  130,  160,  514,  196,  318,  110,  646,  257,  655,
#        1051,  582,  135,  168, 1876, 1021,  111,  250,  358,  582,  582,
#         102,  618, 2281,  582,  245,  211,  582,   69,   91,  146,  707,
#          53,  835,   47,   81,  582,  789,  124,   80,  231,  577,  972,
#         180,  582, 1211,  109, 1896,  582, 1808,  212,   56,  127,  754,
#         281,  103, 1202, 2261,  369,   80,  156,  582,  154,  118,  582,
#          60,  122,  143,  582,  144,  133, 1820,   66,  720,  113,  129,
# ...

# %%
Y_test
# Out:
# array([ 101,  151,  981,  582,  232,   59,   56,  167, 3964,  936,   81,
#         379,  145, 2017,  220,  582,  582,   66, 2794,  191,  582, 5209,
#         582,  270,  582,   96,  582,  170,   61,  207,  582,  250,  157,
#          96,  427,  233, 1419,  395,  196,   47,  157,  115,  582,   94,
#         371, 1548,  582,  582,  315,  582,  224,  320,  115,  748,  364,
#         166,  582,  112, 1688, 1846], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([561.37308364, 561.37308364, 603.98678475, 582.6799342 ,
#        603.98678475, 476.14568143, 625.2936353 , 540.06623309,
#        467.62294121, 569.89582386, 582.6799342 , 518.75938254,
#        625.2936353 , 625.2936353 , 582.6799342 , 646.60048586,
#        582.6799342 , 540.06623309, 582.6799342 , 603.98678475,
#        582.6799342 , 603.98678475, 561.37308364, 582.6799342 ,
#        646.60048586, 476.14568143, 646.60048586, 561.37308364,
#        569.89582386, 561.37308364, 476.14568143, 667.90733641,
#        454.83883088, 569.89582386, 433.53198032, 540.06623309,
#        561.37308364, 625.2936353 , 540.06623309, 561.37308364,
#        476.14568143, 625.2936353 , 518.75938254, 518.75938254,
#        603.98678475, 603.98678475, 540.06623309, 390.91827922,
#        476.14568143, 569.89582386, 518.75938254, 582.6799342 ,
#        646.60048586, 540.06623309, 646.60048586, 603.98678475,
#        561.37308364, 561.37308364, 569.89582386, 582.6799342 ])

# %%
y_pred
# Out:
# array([561.37308364, 561.37308364, 603.98678475, 582.6799342 ,
#        603.98678475, 476.14568143, 625.2936353 , 540.06623309,
#        467.62294121, 569.89582386, 582.6799342 , 518.75938254,
#        625.2936353 , 625.2936353 , 582.6799342 , 646.60048586,
#        582.6799342 , 540.06623309, 582.6799342 , 603.98678475,
#        582.6799342 , 603.98678475, 561.37308364, 582.6799342 ,
#        646.60048586, 476.14568143, 646.60048586, 561.37308364,
#        569.89582386, 561.37308364, 476.14568143, 667.90733641,
#        454.83883088, 569.89582386, 433.53198032, 540.06623309,
#        561.37308364, 625.2936353 , 540.06623309, 561.37308364,
#        476.14568143, 625.2936353 , 518.75938254, 518.75938254,
#        603.98678475, 603.98678475, 540.06623309, 390.91827922,
#        476.14568143, 569.89582386, 518.75938254, 582.6799342 ,
#        646.60048586, 540.06623309, 646.60048586, 603.98678475,
#        561.37308364, 561.37308364, 569.89582386, 582.6799342 ])

# %%
plt.scatter(X_train, Y_train, color = "red")
plt.plot(X_train, regressor.predict(X_train), color = "blue")
plt.title("Correlation between Ejection Fraction and Creatinine Phosphokinase")
plt.xlabel("Ejection Fraction")
plt.ylabel("Creatinine Phosphokinase")
plt.show()

# %%
from sklearn.metrics import r2_score 
r2_score(Y_test, y_pred)
# Out:
# -0.0043412719857747195

# %%
#0.04% correaltion

# %%
#multiple linear regression

# %%
heart
# Out:
#      age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0     75        0                       582         0                 20
# 1     55        0                      7861         0                 38
# 2     65        0                       146         0                 20
# 3     50        1                       111         0                 20
# 4     65        1                       160         1                 20
# ..   ...      ...                       ...       ...                ...
# 294   62        0                        61         1                 38
# 295   55        0                      1820         0                 38
# 296   45        0                      2060         1                 60
# 297   45        0                      2413         0                 38
# 298   50        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
machinelearning5 = heart[["creatinine_phosphokinase", "ejection_fraction", "platelets", "serum_creatinine", "serum_sodium","time", "age"]]

# %%
machinelearning5
# Out:
#      creatinine_phosphokinase  ejection_fraction  platelets  serum_creatinine  \
# 0                         582                 20     265000               1.9
# 1                        7861                 38     263358               1.1
# 2                         146                 20     162000               1.3
# 3                         111                 20     210000               1.9
# 4                         160                 20     327000               2.7
# ..                        ...                ...        ...               ...
# 294                        61                 38     155000               1.1
# 295                      1820                 38     270000               1.2
# 296                      2060                 60     742000               0.8
# 297                      2413                 38     140000               1.4
# 298                       196                 45     395000               1.6
#
#      serum_sodium  time  age
# ...

# %%
X = machinelearning5.iloc[:, :-1].values

# %%
X
# Out:
# array([[5.82000e+02, 2.00000e+01, 2.65000e+05, 1.90000e+00, 1.30000e+02,
#         4.00000e+00],
#        [7.86100e+03, 3.80000e+01, 2.63358e+05, 1.10000e+00, 1.36000e+02,
#         6.00000e+00],
#        [1.46000e+02, 2.00000e+01, 1.62000e+05, 1.30000e+00, 1.29000e+02,
#         7.00000e+00],
#        ...,
#        [2.06000e+03, 6.00000e+01, 7.42000e+05, 8.00000e-01, 1.38000e+02,
#         2.78000e+02],
#        [2.41300e+03, 3.80000e+01, 1.40000e+05, 1.40000e+00, 1.40000e+02,
#         2.80000e+02],
#        [1.96000e+02, 4.50000e+01, 3.95000e+05, 1.60000e+00, 1.36000e+02,
#         2.85000e+02]])

# %%
Y = machinelearning5.iloc[:, -1].values

# %%
Y
# Out:
# array([75, 55, 65, 50, 65, 90, 75, 60, 65, 80, 75, 62, 45, 50, 49, 82, 87,
#        45, 70, 48, 65, 65, 68, 53, 75, 80, 95, 70, 58, 82, 94, 85, 50, 50,
#        65, 69, 90, 82, 60, 60, 70, 50, 70, 72, 60, 50, 51, 60, 80, 57, 68,
#        53, 60, 70, 60, 95, 70, 60, 49, 72, 45, 50, 55, 45, 45, 60, 42, 72,
#        70, 65, 41, 58, 85, 65, 69, 60, 70, 42, 75, 55, 70, 67, 60, 79, 59,
#        51, 55, 65, 44, 57, 70, 60, 42, 60, 58, 58, 63, 70, 60, 63, 65, 75,
#        80, 42, 60, 72, 55, 45, 63, 45, 85, 55, 50, 70, 60, 58, 60, 85, 65,
#        86, 60, 66, 60, 60, 60, 43, 46, 58, 61, 53, 53, 60, 46, 63, 81, 75,
#        65, 68, 62, 50, 80, 46, 50, 61, 72, 50, 52, 64, 75, 60, 72, 62, 50,
#        50, 65, 60, 52, 50, 85, 59, 66, 45, 63, 50, 45, 80, 53, 59, 65, 70,
#        51, 52, 70, 50, 65, 60, 69, 49, 63, 55, 40, 59, 65, 75, 58, 60, 50,
#        60, 60, 40, 80, 64, 50, 73, 45, 77, 45, 65, 50, 60, 63, 45, 70, 60,
# ...

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
X_train
# Out:
# array([[6.60e+01, 2.50e+01, 2.33e+05, 8.00e-01, 1.35e+02, 2.30e+02],
#        [8.55e+02, 5.00e+01, 3.21e+05, 1.00e+00, 1.45e+02, 3.00e+01],
#        [5.90e+01, 6.00e+01, 2.55e+05, 1.10e+00, 1.36e+02, 8.50e+01],
#        ...,
#        [1.02e+02, 6.00e+01, 5.07e+05, 3.20e+00, 1.38e+02, 9.40e+01],
#        [5.82e+02, 3.80e+01, 4.51e+05, 6.00e-01, 1.38e+02, 4.00e+01],
#        [1.71e+02, 6.00e+01, 1.76e+05, 1.10e+00, 1.45e+02, 1.46e+02]])

# %%
X_test
# Out:
# array([[1.01000e+02, 4.00000e+01, 2.26000e+05, 8.00000e-01, 1.41000e+02,
#         1.87000e+02],
#        [1.51000e+02, 4.00000e+01, 2.01000e+05, 1.00000e+00, 1.36000e+02,
#         1.72000e+02],
#        [9.81000e+02, 3.00000e+01, 1.36000e+05, 1.10000e+00, 1.37000e+02,
#         1.10000e+01],
#        [5.82000e+02, 3.50000e+01, 3.71000e+05, 7.00000e-01, 1.40000e+02,
#         1.97000e+02],
#        [2.32000e+02, 3.00000e+01, 1.73000e+05, 1.20000e+00, 1.32000e+02,
#         2.10000e+02],
#        [5.90000e+01, 6.00000e+01, 1.72000e+05, 9.00000e-01, 1.37000e+02,
#         1.07000e+02],
#        [5.60000e+01, 2.50000e+01, 2.37000e+05, 5.00000e+00, 1.30000e+02,
#         2.07000e+02],
#        [1.67000e+02, 4.50000e+01, 3.62000e+05, 1.00000e+00, 1.36000e+02,
#         1.87000e+02],
#        [3.96400e+03, 6.20000e+01, 2.63358e+05, 6.80000e+00, 1.46000e+02,
#         4.30000e+01],
#        [9.36000e+02, 3.80000e+01, 3.04000e+05, 1.10000e+00, 1.33000e+02,
#         8.80000e+01],
# ...

# %%
Y_train
# Out:
# array([45, 82, 70, 64, 75, 65, 66, 45, 78, 75, 70, 70, 47, 70, 77, 70, 60,
#        65, 40, 50, 85, 75, 60, 59, 70, 70, 40, 46, 52, 58, 75, 51, 65, 45,
#        48, 65, 59, 50, 79, 64, 45, 59, 55, 85, 65, 82, 52, 87, 70, 60, 45,
#        60, 63, 45, 65, 63, 53, 50, 72, 68, 60, 62, 50, 70, 56, 50, 45, 68,
#        50, 50, 43, 75, 94, 42, 70, 60, 48, 50, 72, 45, 70, 53, 65, 53, 60,
#        55, 55, 75, 50, 49, 50, 49, 60, 68, 49, 55, 60, 60, 55, 60, 58, 53,
#        85, 53, 72, 60, 62, 63, 70, 60, 50, 61, 60, 73, 60, 65, 63, 90, 63,
#        70, 75, 58, 58, 55, 55, 65, 65, 57, 80, 51, 45, 46, 53, 50, 75, 61,
#        75, 40, 65, 78, 60, 55, 45, 45, 75, 70, 60, 59, 51, 66, 80, 53, 42,
#        50, 65, 60, 60, 42, 62, 86, 80, 69, 60, 70, 70, 60, 55, 60, 61, 50,
#        70, 72, 46, 55, 45, 65, 40, 60, 63, 70, 45, 58, 61, 58, 75, 50, 62,
#        54, 70, 85, 50, 58, 60, 45, 44, 64, 45, 49, 63, 65, 73, 58, 50, 85,
# ...

# %%
Y_test
# Out:
# array([40, 60, 45, 55, 70, 65, 65, 50, 60, 63, 70, 82, 58, 55, 68, 69, 40,
#        70, 55, 52, 80, 42, 60, 53, 73, 60, 45, 55, 62, 53, 42, 42, 65, 60,
#        54, 72, 69, 65, 50, 90, 68, 57, 67, 65, 95, 50, 53, 45, 60, 50, 65,
#        60, 50, 55, 72, 60, 65, 95, 65, 50, 81, 50, 45, 52, 50, 42, 90, 55,
#        65, 51, 52, 58, 67, 70, 72])

# %%
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([59.18327695, 59.8711484 , 64.32697207, 56.0239956 , 57.65210145,
#        64.81055929, 65.38211837, 58.3076621 , 78.71539417, 60.68884753,
#        55.45313129, 68.55418162, 58.38234323, 54.62984226, 63.36130951,
#        59.80997206, 55.97628397, 62.5796763 , 57.50764963, 56.31576   ,
#        59.71855155, 58.31421726, 68.13442316, 67.6931147 , 57.27101528,
#        63.57779695, 58.87304911, 56.25791854, 57.92286333, 58.09742449,
#        64.99141319, 60.63720527, 69.11459272, 61.67869711, 82.50758404,
#        65.43398661, 60.80955088, 58.15447719, 56.17847811, 67.45445772,
#        60.68008806, 62.24559821, 63.88998419, 66.40573588, 61.61396058,
#        59.40355402, 58.27885043, 68.20326324, 64.66837844, 64.68319682,
#        65.74770616, 58.30182644, 58.10464917, 63.03680562, 60.97302174,
#        59.65240645, 60.11285883, 64.97063098, 55.88904984, 59.75312239,
#        58.79962869, 59.61096006, 61.52825091, 55.27115534, 56.59809932,
# ...

# %%
#predict first row

# %%
regressor.predict([[582, 20, 265000, 1.9, 130, 4]])
# Out:
# array([63.32530548])

# %%
#the model predicts that they are 63 years old 
#in actually the person is 75 years old

# %%
#evluate the model

# %%
from sklearn.metrics import r2_score 
r2_score(Y_test, y_pred)
# Out:
# -0.06006218789655371

# %%
#plot the results

# %%
#visualize predicted results

# %%
fig_dims = 5,5
fig, ax = plt.subplots(figsize=fig_dims) 
plt.scatter(Y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted")
plt.show()

# %%
#lots of dispersion no correaltion

# %%
#predicted values vs actual values

# %%
pred_y_df = pd.DataFrame({'Actual Value':Y_test,'Predicted Value':y_pred,'Difference':Y_test-y_pred})

# %%
pred_y_df
# Out:
#     Actual Value  Predicted Value  Difference
# 0             40        59.183277  -19.183277
# 1             60        59.871148    0.128852
# 2             45        64.326972  -19.326972
# 3             55        56.023996   -1.023996
# 4             70        57.652101   12.347899
# ..           ...              ...         ...
# 70            52        61.117973   -9.117973
# 71            58        57.344194    0.655806
# 72            67        57.217524    9.782476
# 73            70        65.121275    4.878725
# 74            72        59.932281   12.067719
#
# [75 rows x 3 columns]

# %%
#wildly inaccurate

# %%
heart
# Out:
#      age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0     75        0                       582         0                 20
# 1     55        0                      7861         0                 38
# 2     65        0                       146         0                 20
# 3     50        1                       111         0                 20
# 4     65        1                       160         1                 20
# ..   ...      ...                       ...       ...                ...
# 294   62        0                        61         1                 38
# 295   55        0                      1820         0                 38
# 296   45        0                      2060         1                 60
# 297   45        0                      2413         0                 38
# 298   50        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...
